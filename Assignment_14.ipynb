# %%
from IPython import display
display.Image('ineuron-logo.png', retina= 0 )

# %% [markdown]
# ### 1. What does RGBA stand for?

# %% [markdown]
# ###### Ans. RGBA stands for Red, Green, Blue, and Alpha.

# %% [markdown]
# ### 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import ImageColor
ImageColor.getcolor('green', 'RGBA')
ImageColor.getcolor('red', 'RGBA')
ImageColor.getcolor('blue', 'RGBA')
# Out:
# (0, 0, 255, 255)

# %% [markdown]
# ### 3. What is a box tuple, and how does it work?

# %%
Ans. A box tuple is a tuple value of four integers: the left edge x-coordinate, the top edge y-coordinate, the width, 
     and the height, respectively.

# %% [markdown]
# ### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
# Ans. For image reshape we can use display module from IPython library

# Ex:

from IPython import display
display.Image('ineuron-logo.png',width=300, height=20)

# %% [markdown]
# ### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
Ans. img.crop((0, 50, 50, 50)) #Notice that you are passing a box tuple to crop()

# %% [markdown]
# ### 6. After making changes to an Image object, how could you save it as an image file?

# %%
Ans. After making change we can save image using by imageObj.save('new_filename.png') method of the Image object.

# %% [markdown]
# ### 7. What module contains Pillow’s shape-drawing code?

# %%
# Ans. ImageDraw contains Pillow's shape-drawing code.

# %% [markdown]
# ### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
# Ans. ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle()

# %% [markdown]
# ## Thank you
